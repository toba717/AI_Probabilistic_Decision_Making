# %% [markdown]
# # Expected Utility in Partially Observable Environment
# ## Takao Oba

# %% [markdown]
# # --------------------------------------------------------
# # Problem Statement
# ![Screen%20Shot%202022-11-27%20at%202.16.44%20AM.png](attachment:Screen%20Shot%202022-11-27%20at%202.16.44%20AM.png)

# %% [markdown]
# # Part 1
# ![Screen%20Shot%202022-11-27%20at%202.16.55%20AM.png](attachment:Screen%20Shot%202022-11-27%20at%202.16.55%20AM.png)

# %% [markdown]
# # Generated Answers
#
# ![Screen%20Shot%202022-11-27%20at%202.17.12%20AM.png](attachment:Screen%20Shot%202022-11-27%20at%202.17.12%20AM.png)

# %% [markdown]
# # Part 2
# ![Screen%20Shot%202022-11-27%20at%202.17.19%20AM.png](attachment:Screen%20Shot%202022-11-27%20at%202.17.19%20AM.png)

# %% [markdown]
# # Generated Answers
# ![Screen%20Shot%202022-11-27%20at%202.17.25%20AM.png](attachment:Screen%20Shot%202022-11-27%20at%202.17.25%20AM.png)

# %% [markdown]
# ![Screen%20Shot%202022-11-27%20at%202.17.29%20AM.png](attachment:Screen%20Shot%202022-11-27%20at%202.17.29%20AM.png)
